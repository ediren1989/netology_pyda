# %% [markdown]
# <a href="https://colab.research.google.com/github/yustinaivanova/netology_statistics/blob/master/dz_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Виды распределений

# %% [markdown]
# Загрузить таблицу и построить график распределений. Найти нормальное распределение.

# %%
import numpy as np
from scipy.stats import t
from scipy.stats import norm
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import io
import requests
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# Таблица цен на дома в Бостоне

# %% [markdown]
# Основные значения:
#
# * CRIM: This is the per capita crime rate by town
# * ZN: This is the proportion of residential land zoned for lots larger than 25,000 sq.ft.
# * INDUS: This is the proportion of non-retail business acres per town.
# * CHAS: This is the Charles River dummy variable (this is equal to 1 if tract bounds river; 0 otherwise)
# * NOX: This is the nitric oxides concentration (parts per 10 million)
# * RM: This is the average number of rooms per dwelling
# * AGE: This is the proportion of owner-occupied units built prior to 1940
# * DIS: This is the weighted distances to five Boston employment centers
# * RAD: This is the index of accessibility to radial highways
# * TAX: This is the full-value property-tax rate per 10,000 dollars
# * PTRATIO: This is the pupil-teacher ratio by town
# * B: This is calculated as 1000(Bk — 0.63)², where Bk is the proportion of people of African American descent by town
# * LSTAT: This is the percentage lower status of the population
# * MEDV: This is the median value of owner-occupied homes in 1000 dollars

# %%
import ssl
# следующая строчка подключает сертификат для защищенного соединения
ssl._create_default_https_context = ssl._create_unverified_context
url='http://yustiks.ru/dataset/housing.csv'
names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data=pd.read_csv(url,  delim_whitespace=True, names=names)
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# Нарисовать частотные графики для всех значений. Можете ли вы найти следующие распределения в данных графиках?
#
#
# 1.   Нормальное - RM
# 2.   Равномерное
# 3.   Биноминальное - MEDV
# 4.   Бернулли - CHAS
# 5.   Геометрическое DIS
# 6.   Логнормальное - LSTAT

# %%
n, bins, patches = plt.hist(data['MEDV'])

plt.xlabel('frequency')
plt.ylabel('MEDV')
plt.title('Частотный график MEDV')
plt.show()

# %%
n, bins, patches = plt.hist(data['LSTAT'])

plt.xlabel('frequency')
plt.ylabel('LSTAT')
plt.title('Частотный график LSTAT')
plt.show()

# %%
n, bins, patches = plt.hist(data['B'])

plt.xlabel('frequency')
plt.ylabel('B')
plt.title('Частотный график B')
plt.show()

# %%
n, bins, patches = plt.hist(data['PTRATIO'])

plt.xlabel('frequency')
plt.ylabel('PTRATIO')
plt.title('Частотный график PTRATIO')
plt.show()

# %%
n, bins, patches = plt.hist(data['TAX'])

plt.xlabel('frequency')
plt.ylabel('TAX')
plt.title('Частотный график TAX')
plt.show()

# %%
n, bins, patches = plt.hist(data['RAD'])

plt.xlabel('frequency')
plt.ylabel('RAD')
plt.title('Частотный график RAD')
plt.show()

# %%
n, bins, patches = plt.hist(data['RAD'])

plt.xlabel('frequency')
plt.ylabel('RAD')
plt.title('Частотный график RAD')
plt.show()

# %%
n, bins, patches = plt.hist(data['DIS'])

plt.xlabel('frequency')
plt.ylabel('DIS')
plt.title('Частотный график DIS')
plt.show()

# %%
n, bins, patches = plt.hist(data['AGE'])

plt.xlabel('frequency')
plt.ylabel('AGE')
plt.title('Частотный график AGE')
plt.show()

# %%
n, bins, patches = plt.hist(data['RM'])

plt.xlabel('frequency')
plt.ylabel('RM')
plt.title('Частотный график RM')
plt.show()

# %%
n, bins, patches = plt.hist(data['NOX'])

plt.xlabel('frequency')
plt.ylabel('NOX')
plt.title('Частотный график NOX')
plt.show()

# %%
n, bins, patches = plt.hist(data['CHAS'])

plt.xlabel('frequency')
plt.ylabel('CHAS')
plt.title('Частотный график CHAS')
plt.show()

# %%
n, bins, patches = plt.hist(data['CRIM'])

plt.xlabel('frequency')
plt.ylabel('CRIM')
plt.title('Частотный график CRIM')
plt.show()

# %%
n, bins, patches = plt.hist(data['ZN'])

plt.xlabel('frequency')
plt.ylabel('ZN')
plt.title('Частотный график ZN')
plt.show()

# %%
n, bins, patches = plt.hist(data['INDUS'])

plt.xlabel('frequency')
plt.ylabel('INDUS')
plt.title('Частотный график INDUS')
plt.show()

# %% [markdown]
# Построить матрицу корреляций для данной таблицы и выбрать максимально коррелирующий атрибут (несколько атрибутов) с ценой на дома (MEDV атрибут). Максимально коррелирующие - RM, LSTAT

# %%
import seaborn as sns
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->матрица корреляций
# gcf() - получение текущей фигуры
fig=plt.gcf()
# set_size_inches() - установить размер фигуры
fig.set_size_inches(18,18)
plt.show()

# %% [markdown]
# Написать **линейную регрессию** на два атрибута. Допустим, мы хотим предсказать цену дома (MEDV) в Бостоне, зная что цена на дом имеет линейную зависимость с атрибутом LSTAT.

# %% [markdown]
# 1.   Разделить данные на 80% тренировочных, 20% тестовых
# 2.   Составить модель линейной регрессии
# 3.   Посчитать ошибку модели на тестовых данных
# 4.   Сделать точечный график данных и полученной прямой линейной регрессии

# %%
from sklearn.linear_model import LinearRegression

# %%
MEDV = np.array(data.MEDV).reshape(-1,1)
LSTAT = np.array(data.LSTAT).reshape(-1,1)
model = LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# x = MEDV,
# y = LSTAT
X_train, X_test, y_train, y_test = train_test_split(
    MEDV,
    LSTAT,
    test_size = 0.2
)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predicted_y = model.predict(X_test)

# %%
model.score(X_test, y_test)
# Out:
# 0.5048641065732922

# %%
plt.xlabel('MEDV')
plt.ylabel('LSTAT')
plt.title('Линейная регрессия от одной переменной')
# Построим прямую для регрессии
# Создадим 100 точек для предсказаний
x = np.linspace(-50, 200, 100)
# Посчитаем предсказанные значения
# y = kx + b
# k = model.coef_
# b = model.intercept_
y = model.coef_*x + model.intercept_
y = np.transpose(y)
plt.plot(x,y)
plt.plot(X_train, y_train, 'r.')
plt.plot(X_test, y_test, 'go')
plt.xlim(0,55)
plt.ylim(0,40)
plt.legend(['Прямая линейной регрессии', 'Тренировочные данные', 'Тестовые данные'])
plt.show()

# %% [markdown]
# Загрузить таблицу Happiness report. Посчитать матрицу ковариаций попарно.

# %%
url="http://yustiks.ru/dataset/world-happiness-report-2019.csv"
dat=pd.read_csv(url)

# %% [markdown]
# Сколько в данной таблице отсутствующих значений? Написать ответ. Если есть отсутствующие значения в выборке country, убрать (drop). Отсутствующих значений в таблице - 11 шт. В выборке country отсутствующих значений нет.

# %%
data = pd.isnull(dat)

# %%
# Out:
#    Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0             False   False         False            False            False
# 1             False   False         False            False            False
# 2             False   False         False            False            False
# 3             False   False         False            False            False
# 4             False   False         False            False            False
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0           False    False       False       False                   False
# 1           False    False       False       False                   False
# 2           False    False       False       False                   False
# 3           False    False       False       False                   False
# 4           False    False       False       False                   False
#
#    Healthy life\nexpectancy
# 0                     False
# ...

# %%
data = (
    data[(data['Positive affect'] == True) | (data['Negative affect'] == True) | (data['Country (region)'] == True) 
        | (data['Ladder'] == True) | (data['SD of Ladder'] == True)  | (data['Social support'] == True) 
        | (data['Freedom'] == True) | (data['Corruption'] == True)  | (data['Generosity'] == True) 
        | (data['Log of GDP\nper capita'] == True)  | (data['Healthy life\nexpectancy'] == True) 
        ]
)
data.head()
# Out:
#     Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 20             False   False         False            False            False
# 24             False   False         False            False            False
# 27             False   False         False            False            False
# 28             False   False         False             True             True
# 36             False   False         False            False            False
#
#     Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 20           False    False        True       False                   False
# 24           False    False       False       False                    True
# 27           False    False        True       False                   False
# 28            True     True        True        True                   False
# 36           False    False        True       False                   False
#
#     Healthy life\nexpectancy
# ...

# %% [markdown]
# Сколько стран в выборке? Написать ответ. 156 стран

# %%
x = dat['Country (region)'].unique()
len(x)
# Out:
# 156

# %% [markdown]
# Построить матрицу корреляций для таблицы. Какие можно сделать выводы? Переменные Ladder,Social Support, Log of GDP\nper capita, Healthy life\nexpectancy сильно коррелируют между собой

# %%
import seaborn as sns
sns.heatmap(dat.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->матрица корреляций
# gcf() - получение текущей фигуры
fig=plt.gcf()
# set_size_inches() - установить размер фигуры
fig.set_size_inches(18,18)
plt.show()

# %% [markdown]
# # Дискретное распределение случайной величины

# %% [markdown]
# Напишите код для моделирования 10 подбрасываний игрального кубика. Начертите диаграму histogram. Какое это распределение? Распределение каждый раз будет разным , в моем случае похоже на равномерное))

# %%
def random(n):
    import random
    i = 0
    random1 = []
    dice = [1,2,3,4,5,6]
    while i < n:
        random.shuffle(dice)
        random1.append(dice[0])
        i += 1
    return(random1)

# %%
n, bins, patches = plt.hist(random(10))

plt.xlabel('random')
plt.ylabel('frequency')
plt.title('Частотный график Freedom')
plt.show()

# %% [markdown]
# Смоделируйте 1000 раз сумму по 100 подбрасываний. Начертите диаграму histogram. Почему график изменился? Почему можно применить центральную предельную теорему? Распределение стремиться к нормальному, а ЦПТ гласит, что сумма большого количество случайных величин всегда стремться к нормальному распределию.

# %%
def random(n):
    import random
    i = 0
    sum_= 0
    random1 = []
    dice = [1,2,3,4,5,6]
    while i < n:
        y = 0
        while y < 101:
            random.shuffle(dice)
            sum_+= dice[0]
            y += 1
        i += 1
        random1.append(sum_)
        sum_ = 0
    return(random1)

# %%
# Out:
# 2414

# %%
n, bins, patches = plt.hist(random(1000))

plt.xlabel('random')
plt.ylabel('frequency')
plt.title('Частотный график Freedom')
plt.show()
